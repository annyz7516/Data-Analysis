# %%
import pandas as pd
df_payment=pd.read_csv('data\olist_order_payments_dataset.csv')
df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_payment.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
df_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_order=pd.read_csv('data\olist_orders_dataset.csv')
df_order
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_payment.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %%
df_payment_group=df_payment[['order_id','payment_value']]
df_payment_group
# Out:
#                                 order_id  payment_value
# 0       b81ef226f3fe1789b1e8b2acac839d17          99.33
# 1       a9810da82917af2d9aefd1278f1dcfa0          24.39
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd          65.71
# 3       ba78997921bbcdc1373bb41e913ab953         107.78
# 4       42fdf880ba16b47b59251dd489d4441a         128.45
# ...                                  ...            ...
# 103881  0406037ad97740d563a178ecc7a2075c         363.31
# 103882  7b905861d7c825891d6347454ea7863f          96.80
# 103883  32609bbb3dd69b3c066a6860554a77bf          47.77
# 103884  b8b61059626efa996a60be9bb9320e10         369.54
# 103885  28bbae6599b09d39ca406b747b6632b1         191.58
#
# [103886 rows x 2 columns]

# %%
df_payment_group=df_payment_group.groupby(['order_id']).sum()
df_payment_group
# Out:
#                                   payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19
# 00018f77f2f0320c557190d7a144bdd3         259.83
# 000229ec398224ef6ca0657da4fc703e         216.87
# 00024acbcdf0a6daa1e931b038114c75          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037         343.40
# fffcd46ef2263f404302a634eb57f7eb         386.53
# fffce4705a9662cd70adb13d4a31832d         116.85
# fffe18544ffabc95dfada21779c9644f          64.71
# fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 1 columns]

# %%
df_payment_group=df_payment_group.reset_index()
df_payment_group
# Out:
#                                order_id  payment_value
# 0      00010242fe8c5a6d1ba2dd792cb16214          72.19
# 1      00018f77f2f0320c557190d7a144bdd3         259.83
# 2      000229ec398224ef6ca0657da4fc703e         216.87
# 3      00024acbcdf0a6daa1e931b038114c75          25.78
# 4      00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                 ...            ...
# 99435  fffc94f6ce00a00581880bf54a75a037         343.40
# 99436  fffcd46ef2263f404302a634eb57f7eb         386.53
# 99437  fffce4705a9662cd70adb13d4a31832d         116.85
# 99438  fffe18544ffabc95dfada21779c9644f          64.71
# 99439  fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 2 columns]

# %%
df_pay_voucher = df_payment[df_payment['payment_type']=='voucher']
df_pay_voucher
# Out:
#                                 order_id  payment_sequential payment_type  \
# 25      5cfd514482e22bc992e7693f0e3e8df7                   2      voucher
# 68      947e9c6bfd83a06953c420ef92d3da6e                   1      voucher
# 70      e3e9e3295f4e1512167c232a0aaae8a5                   1      voucher
# 75      3689194c14ad4e2e7361ebd1df0e77b0                   2      voucher
# 102     21b8b46679ea6482cbf911d960490048                   2      voucher
# ...                                  ...                 ...          ...
# 103747  cf101c3abd3c061ca9f78c1bbb1125af                   3      voucher
# 103750  d0bff47153ef056bb4f884a2ec2f0691                   2      voucher
# 103795  59de68e3ef040153cc9ea7978eaec149                   1      voucher
# 103798  4f259869d5c650af6f847b027032515b                   1      voucher
# 103860  31bc09fdbd701a7a4f9b55b5955b8687                   6      voucher
#
#         payment_installments  payment_value
# ...

# %%
df_payment[df_payment['order_id']=='5cfd514482e22bc992e7693f0e3e8df7']
# Out:
#                                order_id  payment_sequential payment_type  \
# 25     5cfd514482e22bc992e7693f0e3e8df7                   2      voucher
# 57742  5cfd514482e22bc992e7693f0e3e8df7                   1  credit_card
#
#        payment_installments  payment_value
# 25                        1          45.17
# 57742                     4         665.41

# %%
id_list = df_pay_voucher['order_id'].tolist()
df_payment_group['with_voucher'] = df_payment_group['order_id'].isin(id_list)
df_payment_group
# Out:
#                                order_id  payment_value  with_voucher
# 0      00010242fe8c5a6d1ba2dd792cb16214          72.19         False
# 1      00018f77f2f0320c557190d7a144bdd3         259.83         False
# 2      000229ec398224ef6ca0657da4fc703e         216.87         False
# 3      00024acbcdf0a6daa1e931b038114c75          25.78         False
# 4      00042b26cf59d7ce69dfabb4e55b4fd9         218.04         False
# ...                                 ...            ...           ...
# 99435  fffc94f6ce00a00581880bf54a75a037         343.40         False
# 99436  fffcd46ef2263f404302a634eb57f7eb         386.53         False
# 99437  fffce4705a9662cd70adb13d4a31832d         116.85         False
# 99438  fffe18544ffabc95dfada21779c9644f          64.71         False
# 99439  fffe41c64501cc87c801fd61db3f6244          55.79         False
#
# [99440 rows x 3 columns]

# %%
df_payment_group.to_csv('data\olist_payment_group_dataset.csv')
